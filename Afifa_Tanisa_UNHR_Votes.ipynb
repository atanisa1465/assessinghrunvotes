# %% [markdown]
# <a href="https://colab.research.google.com/github/atanisa1465/assessinghrunvotes/blob/main/Afifa_Tanisa_UNHR_Votes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Afifa Tanisa
#
# This notebook aims to assess how members of the United Nations voted on human rights related resolutions in comparison to their human rights scores.
#
# Python Pandas Dataframe was used for this analysis.

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/human-rights-scores.csv'
df1 = pd.read_csv(file_path,encoding = "cp1252")

df1['hr_quartile'] = 0

# df1.iloc[: ,33]

for i in range(len(df1)):
  if df1.iloc[i ,1] < -0.5:
    df1.iloc[i ,2] = 4;
  if df1.iloc[i ,1] >= -0.5 and df1.iloc[i ,1] < 1.5:
    df1.iloc[i ,2] = 3;
  if df1.iloc[i ,1] >= 1.5 and df1.iloc[i ,1] < 3.5:
    df1.iloc[i ,2] = 2;
  if df1.iloc[i ,1] >= 3.5:
    df1.iloc[i ,2] = 1;
  
df1.to_csv('sample_data/countrieswithhrq.csv')

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotes_2000to2021.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/countrieswithhrq.csv'
df2 = pd.read_csv(file_path)

df1 = df1.merge(df2, how="left", left_on=['Countryname'], right_on=['CountryHR'])

df1.to_csv('sample_data/UNVotesHR.csv')
df1

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR.csv'
df1 = pd.read_csv(file_path)

df1 = df1.sort_values('rcid').drop_duplicates(["Countryname", "unres",],keep='last')
print(df1['unres'].nunique())
print(df1['rcid'].nunique())

df1.to_csv('sample_data/UNVotes.csv')
df1

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotes.csv'
df1 = pd.read_csv(file_path)

df13 = df1['rcid'].value_counts() 
df13.to_csv('sample_data/Sample.csv')

firstcol = df13.tail(8)

final_df = df1.loc[~df1['rcid'].isin(firstcol.index)]

df1.to_csv('sample_data/UNVotesHR2.csv')

print(final_df['unres'].nunique())
print(final_df['rcid'].nunique())
df1

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.sort_values('rcid')

df1 = df1[~df1['CountryHR'].isnull()]
df1.to_csv('sample_data/UNVotesHR2.csv')

df1

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

df6 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df6.to_csv('sample_data/unresvotes.csv')
df6

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)

df1 = df1.dropna(axis=0, subset=['unres'])
df2 = pd.crosstab(df1['unres'], df1['vote'])

df2['Plurality'] = -1
ctr = 0
print(df2)

for i in range(len(df2)):
  df3 = df2.iloc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()
  
  df3_yes = df2.iloc[i, 0]
  df3_no = df2.iloc[i, 2]
  df3_abstain = df2.iloc[i, 1]
  df3_notpresent = df2.iloc[i, 3]
  df3_notmember = df2.iloc[i, 4]
  
  if df4 == df3_yes:
    df2.iloc[i, 5] = 1
  if df2.iloc[i, 5] != -1 and df4 == df3_no:
    ctr = ctr + 1
  if df4 == df3_no:
    df2.iloc[i, 5] = 3
  if df2.iloc[i, 5] != -1 and df4 == df3_abstain:
    ctr = ctr + 1
  if df4 == df3_abstain:
    df2.iloc[i, 5] = 2
  if df2.iloc[i, 5] != -1 and df4 == df3_notpresent:
    ctr = ctr + 1
  if df4 == df3_notpresent:
    df2.iloc[i, 5] = 8
  if df2.iloc[i, 5] != -1 and df4 == df3_notmember:
    ctr = ctr + 1
  if df4 == df3_notmember:
    df2.iloc[i, 5] = 9

print(df2.value_counts('Plurality'))

df2.to_csv('sample_data/ResDecision.csv')
print(df2.value_counts('Plurality'))

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
df1.to_csv('sample_data/test.csv')

df1.iloc[:, 0]
df1.shape

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
df1.to_csv('sample_data/test.csv')


df1 = df1.iloc[:, [0,15,16,17,18,19,25]]

df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q4'] = [0, 0, 0, 0, 0]

for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1


df2.to_csv('sample_data/HumanRightsMatrix.csv')


# ---------------------------------------------------------


file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,10,11,12,13,14,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q3'] = [0, 0, 0, 0, 0]

for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')


# ----------------------------------------------------


file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,5,6,7,8,9,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q2'] = [0, 0, 0, 0, 0]

for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')


# ----------------------------------------------------

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hr_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,1,2,3,4,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q1'] = [0, 0, 0, 0, 0]


for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]

  if df4 == df3_yes:
    if df1.iloc[i, 5] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 5] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 5] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 5] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[3, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')

# %%
import numpy as np
import pandas as pd

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hf_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,1,2,3,4,25]]

df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q1'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q1'] = [0, 0, 0, 0, 0]

for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1


df2.to_csv('sample_data/HumanRightsMatrix.csv')


# ---------------------------------------------------------


file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hf_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,6,7,8,9,10,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q2'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q2'] = [0, 0, 0, 0, 0]

for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')


# ----------------------------------------------------

file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hf_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,11,12,13,14,15,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q3'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q3'] = [0, 0, 0, 0, 0]


for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]
  df3_notmember = df1.iloc[i, 5]

  if df4 == df3_yes:
    if df1.iloc[i, 6] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 6] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 6] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 6] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[3, 3] += 1

  if df4 == df3_notmember:
    if df1.iloc[i, 6] == 1:
      df2.iloc[4, 0] += 1
    else:
      if df1.iloc[i, 6] == 3:
        df2.iloc[4, 1] += 1
      else:
        if df1.iloc[i, 6] == 2:
          df2.iloc[4, 2] += 1
        else:
          if df1.iloc[i, 6] == 8:
            df2.iloc[4, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')


# -------------------------------------------------------


file_path = 'sample_data/UNVotesHR2.csv'
df1 = pd.read_csv(file_path)
df1 = df1.loc[df1['hr'] == 1]

file_path = 'sample_data/ResDecision.csv'
df3 = pd.read_csv(file_path)

df1 = pd.crosstab(df1['unres'], [df1['hf_quartile'], df1['vote']])
df1 = df1.merge(df3, how="left", left_on=['unres'], right_on=['unres'])
# df1.to_csv('sample_data/test.csv')

df1 = df1.iloc[:, [0,16,17,18,19,25]]
df2 = pd.DataFrame()

df2['# res passed'] = 0
df2['# res failed'] = 0
df2['# res abstained'] = 0
df2['# res not present'] = 0
df2['# res not member'] = 0

df2.loc['# res passed by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res failed by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res abstained by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res not present by q4'] = [0, 0, 0, 0, 0]
df2.loc['# res not member by q4'] = [0, 0, 0, 0, 0]


for i in range(len(df1)):

  df3 = df1.loc[[i]]
  df4 = df3.max(axis = 1)
  df4 = df4.tolist()

  df3_yes = df1.iloc[i, 1]
  df3_no = df1.iloc[i, 3]
  df3_abstain = df1.iloc[i, 2]
  df3_notpresent = df1.iloc[i, 4]

  if df4 == df3_yes:
    if df1.iloc[i, 5] == 1:
      df2.iloc[0, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[0, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[0, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[0, 3] += 1

  if df4 == df3_no:
    if df1.iloc[i, 5] == 1:
      df2.iloc[1, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[1, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[1, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[1, 3] += 1

  if df4 == df3_abstain:
    if df1.iloc[i, 5] == 1:
      df2.iloc[2, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[2, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[2, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[2, 3] += 1

  if df4 == df3_notpresent:
    if df1.iloc[i, 5] == 1:
      df2.iloc[3, 0] += 1
    else:
      if df1.iloc[i, 5] == 3:
        df2.iloc[3, 1] += 1
      else:
        if df1.iloc[i, 5] == 2:
          df2.iloc[3, 2] += 1
        else:
          if df1.iloc[i, 5] == 8:
            df2.iloc[3, 3] += 1

df2.to_csv('sample_data/HumanRightsMatrix.csv', mode='a')
